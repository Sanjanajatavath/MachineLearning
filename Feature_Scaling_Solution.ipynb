# %% [markdown]
# <a href="https://colab.research.google.com/github/Sanjanajatavath/MachineLearning/blob/main/Feature_Scaling_Solution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("dataset_3.csv")
df.head()
# Out:
#    3    ?  alfa-romero  gas  std   two  convertible  rwd  front  88.60  ...  \
# 0  3    ?  alfa-romero  gas  std   two  convertible  rwd  front   88.6  ...
# 1  1    ?  alfa-romero  gas  std   two    hatchback  rwd  front   94.5  ...
# 2  2  164         audi  gas  std  four        sedan  fwd  front   99.8  ...
# 3  2  164         audi  gas  std  four        sedan  4wd  front   99.4  ...
# 4  2    ?         audi  gas  std   two        sedan  fwd  front   99.8  ...
#
#    130  mpfi  3.47  2.68  9.00  111  5000  21  27  13495
# 0  130  mpfi  3.47  2.68   9.0  111  5000  21  27  16500
# 1  152  mpfi  2.68  3.47   9.0  154  5000  19  26  16500
# 2  109  mpfi  3.19  3.40  10.0  102  5500  24  30  13950
# 3  136  mpfi  3.19  3.40   8.0  115  5500  18  22  17450
# 4  136  mpfi  3.19  3.40   8.5  110  5500  19  25  15250
#
# [5 rows x 26 columns]

# %%
X = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test =train_test_split(X, y, test_size = 0.2, random_state = 1)

# %%
#Importing StandardScaler
from sklearn.preprocessing import StandardScaler
#Creating Instance of StandarScaler
sc = StandardScaler()
#Perform scaling in X_train with fit_transform.
#Here we are applying fit_transform because,
        # fit will calculate mean and standard deviation of X_train
        # transform will actually perform scaling with calculated mean and std.
        # fit_transform method does this both thing in one line of code.
X_train.iloc[:, 4:] = sc.fit_transform(X_train.iloc[:, 4:])

# Here we will only use transform because we have already calculated mean and std.
# Another reason is we don't want to know the mean and std of our test dataset As it
# Lead to information leakage.
X_test.iloc[:, 4:] = sc.transform(X_test.iloc[:, 4:])

# %%
X_train
# Out:
#      3    ?    alfa-romero  gas  std   two convertible  rwd  front  88.60  \
# 153  0   81         toyota  gas  std  four       wagon  4wd  front   95.7
# 180 -1    ?         toyota  gas  std  four       wagon  rwd  front  104.5
# 47   0    ?         jaguar  gas  std  four       sedan  rwd  front  113.0
# 151  1   74         toyota  gas  std  four   hatchback  fwd  front   95.7
# 189  3  256     volkswagen  gas  std   two   hatchback  fwd  front   94.5
# ..  ..  ...            ...  ...  ...   ...         ...  ...    ...    ...
# 133  3  150           saab  gas  std   two   hatchback  fwd  front   99.1
# 137  2   83         subaru  gas  std   two   hatchback  fwd  front   93.7
# 72   0    ?  mercedes-benz  gas  std  four       sedan  rwd  front  120.9
# 140  0  102         subaru  gas  std  four       sedan  fwd  front   97.2
# 37   0  106          honda  gas  std   two   hatchback  fwd  front   96.5
#
#      ...   four  130  mpfi  3.47  2.68 9.00  111  5000  21  27
# 153  ...   four   92  2bbl  3.05  3.03  9.0   62  4800  27  32
# 180  ...    six  161  mpfi  3.27  3.35  9.2  156  5200  19  24
# 47   ...    six  258  mpfi  3.63  4.17  8.1  176  4750  15  19
# 151  ...   four   92  2bbl  3.05  3.03  9.0   62  4800  31  38
# 189  ...   four  109  mpfi  3.19  3.40  8.5   90  5500  24  29
# ..   ...    ...  ...   ...   ...   ...  ...  ...   ...  ..  ..
# 133  ...   four  121  mpfi  2.54  2.07  9.3  110  5250  21  28
# 137  ...   four   97  2bbl  3.62  2.36  9.0   69  4900  31  36
# 72   ...  eight  308  mpfi  3.80  3.35  8.0  184  4500  14  16
# 140  ...   four  108  2bbl  3.62  2.64  9.5   82  4800  32  37
# 37   ...   four  110  1bbl  3.15  3.58  9.0   86  5800  27  33
#
# [163 rows x 25 columns]

# %%
X_test
# Out:
#      3    ?    alfa-romero     gas    std   two  convertible  rwd  front  \
# 127  3    ?        porsche     gas    std   two  convertible  rwd   rear
# 203 -1   95          volvo     gas  turbo  four        sedan  rwd  front
# 18   1   98      chevrolet     gas    std   two    hatchback  fwd  front
# 175 -1   65         toyota     gas    std  four        sedan  fwd  front
# 196 -1   74          volvo     gas    std  four        wagon  rwd  front
# 31   1  101          honda     gas    std   two    hatchback  fwd  front
# 28   3  145          dodge     gas  turbo   two    hatchback  fwd  front
# 40   0   85          honda     gas    std  four        sedan  fwd  front
# 95   1  122         nissan     gas    std  four        sedan  fwd  front
# 38   0   85          honda     gas    std  four        sedan  fwd  front
# 145  0   89         subaru     gas    std  four        wagon  fwd  front
# 44   0    ?          isuzu     gas    std  four        sedan  fwd  front
# 51   1  104          mazda     gas    std   two    hatchback  fwd  front
# 69  -1   93  mercedes-benz  diesel  turbo  four        sedan  rwd  front
# 4    2    ?           audi     gas    std   two        sedan  fwd  front
# 93   1  128         nissan     gas    std   two        sedan  fwd  front
# 172 -1   65         toyota     gas    std  four        sedan  fwd  front
# 150  1   87         toyota     gas    std   two    hatchback  fwd  front
# 11   0  188            bmw     gas    std   two        sedan  rwd  front
# 117  1  119       plymouth     gas    std   two    hatchback  fwd  front
# 35   0   78          honda     gas    std  four        wagon  fwd  front
# 99   0  106         nissan     gas    std  four        sedan  fwd  front
# 89   1  128         nissan  diesel    std   two        sedan  fwd  front
# 202 -1   95          volvo  diesel  turbo  four        sedan  rwd  front
# 118  1  119       plymouth     gas  turbo   two    hatchback  fwd  front
# 29   2  137          honda     gas    std   two    hatchback  fwd  front
# 58   1  129          mazda     gas    std   two    hatchback  fwd  front
# 16   0    ?            bmw     gas    std  four        sedan  rwd  front
# 90   1  128         nissan     gas    std   two        sedan  fwd  front
# 114  0  161         peugot     gas    std  four        sedan  rwd  front
# 103  3  194         nissan     gas    std   two    hatchback  rwd  front
# 169  2  134         toyota     gas    std   two      hardtop  rwd  front
# 34   0  110          honda     gas    std  four        sedan  fwd  front
# 27  -1  110          dodge     gas    std  four        wagon  fwd  front
# 181  2  122     volkswagen  diesel    std   two        sedan  fwd  front
# 143  0  102         subaru     gas    std  four        sedan  4wd  front
# 98   0  106         nissan     gas    std  four    hatchback  fwd  front
# 102  0  108         nissan     gas    std  four        sedan  fwd  front
# 124  3  186        porsche     gas    std   two    hatchback  rwd  front
# 198 -1   74          volvo     gas  turbo  four        wagon  rwd  front
# 168  2  134         toyota     gas    std   two    hatchback  rwd  front
#
#      88.60  ...  four  130  mpfi  3.47  2.68  9.00  111  5000  21  27
# 127   89.5  ...   six  194  mpfi  3.74  2.90   9.5  207  5900  17  25
# 203  109.1  ...  four  141  mpfi  3.78  3.15   9.5  114  5400  19  25
# 18    94.5  ...  four   90  2bbl  3.03  3.11   9.6   70  5400  38  43
