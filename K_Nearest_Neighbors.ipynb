# %% [markdown]
# <a href="https://colab.research.google.com/github/Sanjanajatavath/MachineLearning/blob/main/K_Nearest_Neighbors.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import necessary libraries
import pandas as pd
import numpy as np

# %%
#read csv file
df=pd.read_csv("/content/breast_cancer_diagnosis.csv")

# %%
df.columns
# Out:
# Index(['id', 'diagnosis', 'Radius_mean', 'Texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
#choose first 10 columns for the models data
df=df[['id','diagnosis','Radius_mean','Texture_mean','perimeter_mean',
       'area_mean','smoothness_mean','compactness_mean','concavity_mean',
       'concave points_mean','symmetry_mean']]

# %%
#divide the data into inputs and outputs
X= df.drop('diagnosis',axis=1)
y = df['diagnosis']

# %%
#split into train and testing data
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, stratify = y, random_state = 1)

# %%
#import KNeighborsClassifier from the library and train the model
from sklearn.neighbors import KNeighborsClassifier
model=KNeighborsClassifier(n_neighbors=2)
model.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=2)

# %%
#predict the outputs
y_test_hat=model.predict(X_test)
Results=pd.DataFrame({'actual':y_test,'prediction':y_test_hat})
Results.head(10)
# Out:
#     actual prediction
# 399      B          B
# 16       M          M
# 369      M          M
# 174      B          B
# 71       B          B
# 354      B          B
# 212      M          B
# 137      B          B
# 151      B          B
# 452      B          B

# %%
#predict the outputs
y_test_hat=model.predict(X_test)
Rresults=pd.DataFrame({'actual':y_test,'prediction':y_test_hat})
Rresults.head()
# Out:
#     actual prediction
# 399      B          B
# 16       M          M
# 369      M          M
# 174      B          B
# 71       B          B

# %%
#evaluate the model using confusion matrix
from sklearn.metrics import confusion_matrix,recall_score,precision_score
cm=confusion_matrix(y_test,y_test_hat)
print(cm)
# Out:
# [[103   4]
#  [ 33  31]]

# %%
#print the classification report
from sklearn.metrics import classification_report
print(classification_report(y_test,y_test_hat))
# Out:
#               precision    recall  f1-score   support
#
#            B       0.76      0.96      0.85       107
#            M       0.89      0.48      0.63        64
#
#     accuracy                           0.78       171
#    macro avg       0.82      0.72      0.74       171
# weighted avg       0.81      0.78      0.76       171

# %%
#experiment with k values as 7
model=KNeighborsClassifier(n_neighbors=7)
model.fit(X_train,y_train)
y_test_hat=model.predict(X_test)
Results=pd.DataFrame({'actual':y_test,'prediction':y_test_hat})
Results.head(10)
# Out:
#     actual prediction
# 399      B          B
# 16       M          M
# 369      M          B
# 174      B          B
# 71       B          B
# 354      B          B
# 212      M          B
# 137      B          B
# 151      B          M
# 452      B          B

# %%
#print classification report
print(classification_report(y_test,y_test_hat))
# Out:
#               precision    recall  f1-score   support
#
#            B       0.71      0.83      0.77       107
#            M       0.61      0.44      0.51        64
#
#     accuracy                           0.68       171
#    macro avg       0.66      0.63      0.64       171
# weighted avg       0.67      0.68      0.67       171
